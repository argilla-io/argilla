# %%
from observe.client import Client, AuthenticatedClient

# %%
client = Client(base_url="https://observe-dev.biome.recogn.ai/")

# %%
from observe.api.security import login_for_access_token
from observe.models import * 
from observe.api.text_classification import bulk_records, search_records

# %%
token = login_for_access_token.sync(client=client, form_data=BodyLoginForAccessTokenSecurityTokenPost(username="johndoe", password="secret", grant_type="password"))
# Out:
# {'url': 'http://localhost:8000/security/token', 'headers': {}, 'cookies': {}, 'timeout': 5.0, 'data': {'username': 'johndoe', 'password': 'secret', 'grant_type': 'password', 'scope': '', 'client_id': <observe.types.Unset object at 0x7fad1fc65c10>, 'client_secret': <observe.types.Unset object at 0x7fad1fc65c10>, 'additional_properties': {}}}

# %%
token.access_token
# Out:
# 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiJqb2huZG9lIiwiZXhwIjoxNjExNzQ3MjUzfQ.r0f_qTOujq5Cyl1pNLIJl4m6jaJPG4EP6n8lL8YPE4w'

# %%
auth_client = AuthenticatedClient(base_url=client.base_url, token="eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiJ0ZXN0VXNlciIsImV4cCI6MTYxNDM3NTQ4MX0.NvYSb0WOLvp1y1wulHZ-qa1c66wQuDygpv1uorTg7g4")

# %%
auth_client
# Out:
# AuthenticatedClient(base_url='http://localhost:8000', cookies={}, headers={}, timeout=5.0, token='eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiJ0ZXN0VXNlciIsImV4cCI6MTYxNDM3NTQ4MX0.NvYSb0WOLvp1y1wulHZ-qa1c66wQuDygpv1uorTg7g4')

# %%
body = BodySearchRecordsClassificationDatasets_DatasetId__SearchPost.from_dict({})
search = search_records.sync(client=auth_client, dataset_id="serving-fake-model-predictions-logs", json_body=body)

# %%
search
# Out:
# TextClassificationResults(total=2000, records=[TextClassificationRecordOUT(inputs=TextClassificationRecordOUTInputs(additional_properties={'text': 'Bilitza Physiotherapie Benecke'}), id='0', metadata=TextClassificationRecordOUTMetadata(additional_properties={'gold': 'Physiotherapie', 'input': 'Bilitza Physiotherapie Benecke'}), status=None, prediction=TextClassificationAnnotation(agent='predict(text:str)', labels=[ClassPrediction(class_='A', confidence=0.9, additional_properties={}), ClassPrediction(class_='B', confidence=0.1, additional_properties={})], additional_properties={}), annotation=TextClassificationAnnotation(agent='test_ds', labels=[ClassPrediction(class_='Physiotherapie', confidence=1.0, additional_properties={})], additional_properties={}), multi_label=False, explanation=TextClassificationRecordOUTExplanation(additional_properties={}), last_updated=datetime.datetime(2021, 1, 14, 13, 58, 59, 674583), predicted=None, additional_properties={}), TextClassificationRecordOUT(inputs=TextClassificationRecordOUTInputs(additional_properties={'text': 'Kempke Unternehmensberatung'}), id='1', metadata=TextClassificationRecordOUTMetadata(additional_properties={'gold': 'Unternehmensberatungen', 'input': 'Kempke Unternehmensberatung'}), status=None, prediction=TextClassificationAnnotation(agent='predict(text:str)', labels=[ClassPrediction(class_='A', confidence=0.9, additional_properties={}), ClassPrediction(class_='B', confidence=0.1, additional_properties={})], additional_properties={}), annotation=TextClassificationAnnotation(agent='test_ds', labels=[ClassPrediction(class_='Unternehmensberatungen', confidence=1.0, additional_properties={})], additional_properties={}), multi_label=False, explanation=TextClassificationRecordOUTExplanation(additional_properties={}), last_updated=datetime.datetime(2021, 1, 14, 13, 58, 59, 674712), predicted=None, additional_properties={}), TextClassificationRecordOUT(inputs=TextClassificationRecordOUTInputs(additional_properties={'text': 'Jürgen Kremer Sietower Bauunternehmen Gmbh'}), id='2', metadata=TextClassificationRecordOUTMetadata(additional_properties={'gold': 'Tiefbau', 'input': 'Jürgen Kremer Sietower Bauunternehmen Gmbh'}), status=None, prediction=TextClassificationAnnotation(agent='predict(text:str)', labels=[ClassPrediction(class_='A', confidence=0.9, additional_properties={}), ClassPrediction(class_='B', confidence=0.1, additional_properties={})], additional_properties={}), annotation=TextClassificationAnnotation(agent='test_ds', labels=[ClassPrediction(class_='Tiefbau', confidence=1.0, additional_properties={})], additional_properties={}), multi_label=False, explanation=TextClassificationRecordOUTExplanation(additional_properties={}), last_updated=datetime.datetime(2021, 1, 14, 13, 58, 59, 674823), predicted=None, additional_properties={}), TextClassificationRecordOUT(inputs=TextClassificationRecordOUTInputs(additional_properties={'text': 'Kolping Bildungswerk In Der Diözese Augsburg E.v. Brandes'}), id='3', metadata=TextClassificationRecordOUTMetadata(additional_properties={'gold': 'Vereine', 'input': 'Kolping Bildungswerk In Der Diözese Augsburg E.v. Brandes'}), status=None, prediction=TextClassificationAnnotation(agent='predict(text:str)', labels=[ClassPrediction(class_='A', confidence=0.9, additional_properties={}), ClassPrediction(class_='B', confidence=0.1, additional_properties={})], additional_properties={}), annotation=TextClassificationAnnotation(agent='test_ds', labels=[ClassPrediction(class_='Vereine', confidence=1.0, additional_properties={})], additional_properties={}), multi_label=False, explanation=TextClassificationRecordOUTExplanation(additional_properties={}), last_updated=datetime.datetime(2021, 1, 14, 13, 58, 59, 674922), predicted=None, additional_properties={}), TextClassificationRecordOUT(inputs=TextClassificationRecordOUTInputs(additional_properties={'text': 'Mittendrin Lübeck E.v.'}), id='4', metadata=TextClassificationRecordOUTMetadata(additional_propertie ...
